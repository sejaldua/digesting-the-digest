# %% [markdown]
# <a href="https://colab.research.google.com/github/sejaldua/digesting-the-digest/blob/main/BERTopic_DTM.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## Dynamic Topic Models
# Dynamic topic models can be used to analyze the evolution of topics of a collection of documents over time.
#
# <br>
#
# <img src="https://raw.githubusercontent.com/MaartenGr/BERTopic/master/images/logo.png" width="40%">

# %% [markdown]
# # Installing BERTopic
#
# We start by installing BERTopic from PyPi:

# %%
# %%capture
# !pip install bertopic

# %% [markdown]
# ## Restart the Notebook
# After installing BERTopic, some packages that were already loaded were updated and in order to correctly use them, we should now restart the notebook.
#
# From the Menu:
#
# Runtime → Restart Runtime

# %% [markdown]
# # **Data**
# For this tutorial, we will be needing to extract all Trump's Tweet from his @realDonalTrump account. We will be removing all retweet and focus on his original tweets.
#
# Moreover, since we are looking at his tweets over time, we will be saving all timestamps related to his tweets.

# %%
import re
import pandas as pd
from datetime import datetime

# Load data
df = pd.read_csv('https://raw.githubusercontent.com/sejaldua/digesting-the-digest/main/article_data_via_gmail_api.csv')

# Get variables
titles = df.Title.to_list()
dates = df['Date'].apply(lambda x: pd.Timestamp(x))

# %%
df
# Out:
#                            Date  ... Minutes
# 0     2021-08-11 11:40:00+00:00  ...       5
# 1     2021-08-11 11:40:00+00:00  ...       6
# 2     2021-08-11 11:40:00+00:00  ...       5
# 3     2021-08-11 11:40:00+00:00  ...       2
# 4     2021-08-11 11:40:00+00:00  ...       5
# ...                         ...  ...     ...
# 9160  2020-01-01 16:30:00+00:00  ...      10
# 9161  2020-01-01 16:30:00+00:00  ...       3
# 9162  2020-01-01 16:30:00+00:00  ...      14
# 9163  2020-01-01 16:30:00+00:00  ...       8
# 9164  2020-01-01 16:30:00+00:00  ...       9
#
# [9165 rows x 6 columns]

# %% [markdown]
# # **Dynamic Topic Modeling**

# %% [markdown]
# ## Basic Topic Model
# To perform Dynamic Topic Modeling with BERTopic we will first need to create a basic topic model using all tweets. The temporal aspect will be ignored as we are, for now, only interested in the topics that reside in those tweets.

# %%
from bertopic import BERTopic
topic_model = BERTopic(min_topic_size=30, verbose=True)
topics, _ = topic_model.fit_transform(titles)
# Out:
# /usr/local/lib/python3.7/dist-packages/distributed/config.py:20: YAMLLoadWarning: calling yaml.load() without Loader=... is deprecated, as the default Loader is unsafe. Please read https://msg.pyyaml.org/load for full details.
#   defaults = yaml.load(f)
# HBox(children=(FloatProgress(value=0.0, description='Downloading', max=690.0, style=ProgressStyle(description_…
# HBox(children=(FloatProgress(value=0.0, description='Downloading', max=3693.0, style=ProgressStyle(description…
# HBox(children=(FloatProgress(value=0.0, description='Downloading', max=629.0, style=ProgressStyle(description_…
# HBox(children=(FloatProgress(value=0.0, description='Downloading', max=122.0, style=ProgressStyle(description_…
# HBox(children=(FloatProgress(value=0.0, description='Downloading', max=229.0, style=ProgressStyle(description_…
# HBox(children=(FloatProgress(value=0.0, description='Downloading', max=90895153.0, style=ProgressStyle(descrip…
# HBox(children=(FloatProgress(value=0.0, description='Downloading', max=53.0, style=ProgressStyle(description_w…
# HBox(children=(FloatProgress(value=0.0, description='Downloading', max=112.0, style=ProgressStyle(description_…
# HBox(children=(FloatProgress(value=0.0, description='Downloading', max=466081.0, style=ProgressStyle(descripti…
# HBox(children=(FloatProgress(value=0.0, description='Downloading', max=516.0, style=ProgressStyle(description_…
# HBox(children=(FloatProgress(value=0.0, description='Downloading', max=231508.0, style=ProgressStyle(descripti…
# HBox(children=(FloatProgress(value=0.0, description='Downloading', max=190.0, style=ProgressStyle(description_…
# HBox(children=(FloatProgress(value=0.0, description='Batches', max=287.0, style=ProgressStyle(description_widt…
# 2021-08-11 23:10:05,450 - BERTopic - Transformed documents to Embeddings
# /usr/local/lib/python3.7/dist-packages/numba/np/ufunc/parallel.py:363: NumbaWarning: The TBB threading layer requires TBB version 2019.5 or later i.e., TBB_INTERFACE_VERSION >= 11005. Found TBB_INTERFACE_VERSION = 9107. The TBB threading layer is disabled.
#   warnings.warn(problem)
# 2021-08-11 23:10:38,472 - BERTopic - Reduced dimensionality with UMAP
# 2021-08-11 23:10:38,954 - BERTopic - Clustered UMAP embeddings with HDBSCAN

# %% [markdown]
# We can then extract most frequent topics:

# %%
freq = topic_model.get_topic_info(); freq.head(10)
# Out:
#    Topic  Count                                            Name
# 0     -1   2657                          -1_this_why_when_about
# 1      0    432         0_scientist_scientists_interview_career
# 2      1    429            1_libraries_useful_functions_science
# 3      2    338                 2_learning_models_algorithms_ml
# 4      3    325           3_developer_code_programming_software
# 5      4    207                        4_react_app_create_hooks
# 6      5    160                  5_life_habit_successful_habits
# 7      6    158                  6_design_ux_designer_portfolio
# 8      7    153  7_regression_bayesian_probability_distribution
# 9      8    139             8_dating_relationship_love_marriage

# %% [markdown]
# -1 refers to all outliers and should typically be ignored. Next, let's take a look at a frequent topic that were generated:

# %%
topic_nr = freq.iloc[3]["Topic"]  # We select a frequent topic
topic_model.get_topic(topic_nr)   # You can select a topic number as shown above
# Out:
# [('learning', 0.07957643550746428),
#  ('models', 0.02887036768514761),
#  ('algorithms', 0.0227672839565982),
#  ('ml', 0.01948218486023126),
#  ('model', 0.018236085881024336),
#  ('algorithm', 0.017246406874633566),
#  ('selection', 0.013393544039876033),
#  ('bias', 0.01171935103489153),
#  ('regression', 0.009375006606619066),
#  ('loss', 0.008370965024922522)]

# %% [markdown]
# We can visualize the basic topics that were created with the Intertopic Distance Map. This allows us to judge visually whether the basic topics are sufficient before proceeding to creating the topics over time.

# %%
fig = topic_model.visualize_topics(); fig
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-latest.min.js"></script>                <div id="dd4069cf-8d40-4877-a85f-e28082f62936" class="plotly-graph-div" style="height:650px; width:650px;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("dd4069cf-8d40-4877-a85f-e28082f62936")) {                    Plotly.newPlot(                        "dd4069cf-8d40-4877-a85f-e28082f62936",                        [{"customdata": [[8.234820365905762, -3.561659336090088, 0, "scientist | scientists | interview | career | questions", 432], [8.826691627502441, -2.3125534057617188, 1, "libraries | useful | functions | science | comprehension", 429], [8.398359298706055, -3.6852428913116455, 2, "learning | models | algorithms | ml | model", 338], [8.391860961914062, -3.1918563842773438, 3, "developer | code | programming | software | developers", 325], [8.030647277832031, -2.1900010108947754, 4, "react | app | create | hooks | hook", 207], [9.86030101776123, 3.7108957767486572, 5, "life | habit | successful | habits | things", 160], [9.340398788452148, 3.4104347229003906, 6, "design | ux | designer | portfolio | designers", 158], [3.6545562744140625, 5.331055641174316, 7, "regression | bayesian | probability | distribution | likelihood", 153], [10.184739112854004, 3.5280752182006836, 8, "dating | relationship | love | marriage | boyfriend", 139], [-1.669937252998352, 11.012463569641113, 9, "visualization | charts | visualizations | chart | validate", 136], [-4.099888324737549, -2.339667558670044, 10, "scraping | web | scrape | scrapy | selenium", 120], [8.964337348937988, -2.5753066539764404, 11, "pandas | dataframe | frame | dataframes | json", 119], [16.314804077148438, 4.435458660125732, 12, "covid19 | vaccine | covid | autoimmune | vaccines", 116], [4.106986045837402, 4.760567665100098, 13, "sentiment | twitter | messages | tweets | nlp", 115], [9.311565399169922, 3.390406370162964, 14, "ai | artificial | intelligence | ais | ethics", 114], [-4.720940113067627, -4.384224891662598, 15, "classification | similarity | nlp | labeling | multiclass", 112], [10.36225700378418, 3.665900230407715, 16, "black | racism | racist | women | grandma", 111], [9.240253448486328, 3.3131771087646484, 17, "facebook | amazon | linkedin | facebooks | social", 110], [16.36459732055664, 4.484918594360352, 18, "coronavirus | outbreak | disease | viral | worry", 109], [-4.9312520027160645, -4.757225513458252, 19, "language | text | english | extraction | tapas", 104], [4.238511085510254, 4.451449394226074, 20, "tweets | twitter | tweet | tweepy | twitters", 102], [9.659890174865723, 4.051219940185547, 21, "writer | write | writing | writers | wrote", 99], [8.592607498168945, -3.2597005367279053, 22, "apple | mac | apples | macos | iphone", 98], [-1.70720636844635, 11.049670219421387, 23, "plotly | visualizations | visualization | plots | matplotlib", 93], [14.819099426269531, 10.62066650390625, 24, "battery | tesla | batteries | uber | drivers", 92], [4.348026275634766, 4.368890762329102, 25, "spotify | music | spotifys | audio | genres", 91], [7.5886640548706055, 12.196513175964355, 26, "eat | diet | coffee | food | alcohol", 91], [4.243396759033203, 4.811282157897949, 27, "recommendation | recommender | recommendations | reinforcement | seattle", 90], [-4.405439376831055, -3.8838117122650146, 28, "neural | networks | tensorflow | generative | deepmind", 88], [14.524112701416016, 10.327849388122559, 29, "universe | earth | moon | horoscope | hole", 87], [-4.4815216064453125, -3.789074659347534, 30, "clustering | kmeans | detection | fraud | dbscan", 86], [7.546341896057129, 12.15413761138916, 31, "exercise | gym | workout | runner | training", 86], [8.698407173156738, -2.291515827178955, 32, "frameworks | code | 2020 | java | stop", 86], [9.603822708129883, 4.133691310882568, 33, "podcast | podcasts | podcasting | podcastsor | ...

# %% [markdown]
# ## Topics over Time
# Before we start with the Dynamic Topic Modeling step, it is important that you are satisfied with the topics that were created previously. We are going to be using those specific topics as a base for Dynamic Topic Modeling.
#
# Thus, this step will essentially show you how the topics that were defined previously have evolved over time.

# %% [markdown]
# There are a few important parameters that you should take note of, namely:
#
# * `docs`
#   * These are the tweets that we are using
# * `topics`
#   * The topics that we have created before
# * `timestamps`
#   * The timestamp of each tweet/document
# * `global_tuning`
#   * Whether to average the topic representation of a topic at time *t* with its global topic representation
# * `evolution_tuning`
#   * Whether to average the topic representation of a topic at time *t* with the topic representation of that topic at time *t-1*
# * `nr_bins`
#   * The number of bins to put our timestamps into. It is computationally inefficient to extract the topics at thousands of different timestamps. Therefore, it is advised to keep this value below 20.

# %%
topics_over_time = topic_model.topics_over_time(docs=titles, 
                                                topics=topics, 
                                                timestamps=dates, 
                                                global_tuning=True, 
                                                evolution_tuning=True, 
                                                nr_bins=20)
# Out:
# 20it [00:24,  1.23s/it]

# %% [markdown]
# ## Visualize Topics over Time
# After having created our `topics_over_time`, we will have to visualize those topics as accessing them becomes a bit more difficult with the added temporal dimension.
#
# To do so, we are going to visualize the distribution of topics over time based on their frequency. Doing so allows us to see how the topics have evolved over time. Make sure to hover over any point to see how the topic representation at time *t* differs from the global topic representation.

# %%
topic_model.visualize_topics_over_time(topics_over_time, top_n_topics=10)
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-latest.min.js"></script>                <div id="03e201f1-7d8e-43cb-9ac9-565f6b18392c" class="plotly-graph-div" style="height:450px; width:1250px;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("03e201f1-7d8e-43cb-9ac9-565f6b18392c")) {                    Plotly.newPlot(                        "03e201f1-7d8e-43cb-9ac9-565f6b18392c",                        [{"hoverinfo": "text", "hovertext": ["<b>Topic 0</b><br>Words: science, scientist, 10nasas, sql, interview", "<b>Topic 0</b><br>Words: scientist, scientists, interview, engineers, documentationbook", "<b>Topic 0</b><br>Words: science, scientist, truths, career, scientists", "<b>Topic 0</b><br>Words: scientist, career, interviewing, internship, questions", "<b>Topic 0</b><br>Words: scientist, airbnb, company, scientists, teichmanndataiq", "<b>Topic 0</b><br>Words: scientist, employees, scientists, databases, career", "<b>Topic 0</b><br>Words: scientists, science, scientist, fda, volunteer", "<b>Topic 0</b><br>Words: scientist, moocs, management, interview, hdf5", "<b>Topic 0</b><br>Words: skills, scientists, seasoned, datascience, tech", "<b>Topic 0</b><br>Words: scientists, alteryx, hired, skills, scientist", "<b>Topic 0</b><br>Words: scientists, scientist, outcomes, reckoning, future", "<b>Topic 0</b><br>Words: science, scientists, scientist, interview, resumes", "<b>Topic 0</b><br>Words: interview, microsoft, analyst, intelligence, business", "<b>Topic 0</b><br>Words: scientist, science, courses, scientists, sciences", "<b>Topic 0</b><br>Words: science, scientist, scientists, business, datathon", "<b>Topic 0</b><br>Words: projects, science, scientist, questions, scientists", "<b>Topic 0</b><br>Words: science, scientist, scientists, techbio, biotech", "<b>Topic 0</b><br>Words: science, programmersdata, scientists, interview, scientist", "<b>Topic 0</b><br>Words: scientists, science, riskfree, jobs, million", "<b>Topic 0</b><br>Words: science, project, job, degree, programming"], "marker": {"color": "#E69F00"}, "mode": "lines", "name": "0_scientist_scientists_interview_career", "type": "scatter", "x": ["2020-01-01T02:23:34.200000+00:00", "2020-01-31T01:51:30+00:00", "2020-02-29T11:13:00+00:00", "2020-03-29T20:34:30+00:00", "2020-04-28T05:56:00+00:00", "2020-05-27T15:17:30+00:00", "2020-06-26T00:39:00+00:00", "2020-07-25T10:00:30+00:00", "2020-08-23T19:22:00+00:00", "2020-09-22T04:43:30+00:00", "2020-10-21T14:05:00+00:00", "2020-11-19T23:26:30+00:00", "2020-12-19T08:48:00+00:00", "2021-01-17T18:09:30+00:00", "2021-02-16T03:31:00+00:00", "2021-03-17T12:52:30+00:00", "2021-04-15T22:14:00+00:00", "2021-05-15T07:35:30+00:00", "2021-06-13T16:57:00+00:00", "2021-07-13T02:18:30+00:00"], "y": [20, 17, 9, 17, 15, 25, 12, 17, 37, 22, 20, 37, 30, 30, 27, 18, 28, 14, 14, 23]}, {"hoverinfo": "text", "hovertext": ["<b>Topic 1</b><br>Words: bars, loops, args, kwargs, tips", "<b>Topic 1</b><br>Words: lists, dunders, comprehension, loops, programming", "<b>Topic 1</b><br>Words: tryexcept, loops, tricks, trees, stacks", "<b>Topic 1</b><br>Words: code, decorators, builtin, productivity, toolbox", "<b>Topic 1</b><br>Words: php, mistakes, code, developers, ml", "<b>Topic 1</b><br>Words: code, module, enums, pythonista, boolean", "<b>Topic 1</b><br>Words: ifelse, fpgrowth, pip, annotations, comprehension", "<b>Topic 1</b><br>Words: gui, easiest, string, methods, debug", "<b>Topic 1</b><br>Words: features, dj, accumulate, neglected, polynote", "<b>Topic 1</b><br>Words: libraries, scikitlearn, klib, steganography, neo4j", "<b>Topic 1</b><br>Words: steganography, program, scikitimage, vault, sdv", "<b>Topic 1</b><br>Words: homepart, initpy, datapane, preprocess, simulating", "<b>Topic 1</b><br>Words: preprocess, package, icecream, libraryparsl, debug", "<b>Topic 1</b><br>Words: code, sweetviz, useful, upgrade, eas ...

# %%
topic_model.visualize_heatmap()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-latest.min.js"></script>                <div id="104a0d86-db98-48ab-a2d0-d9dea5d4cbe8" class="plotly-graph-div" style="height:800px; width:800px;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("104a0d86-db98-48ab-a2d0-d9dea5d4cbe8")) {                    Plotly.newPlot(                        "104a0d86-db98-48ab-a2d0-d9dea5d4cbe8",                        [{"coloraxis": "coloraxis", "hovertemplate": "x: %{x}<br>y: %{y}<br>Similarity Score: %{z}<extra></extra>", "name": "0", "type": "heatmap", "x": ["-1_this_why_when", "0_scientist_scientists_inte...", "1_libraries_useful_functions", "2_learning_models_algorithms", "3_developer_code_programming", "4_react_app_create", "5_life_habit_successful", "6_design_ux_designer", "7_regression_bayesian_proba...", "8_dating_relationship_love", "9_visualization_charts_visu...", "10_scraping_web_scrape", "11_pandas_dataframe_frame", "12_covid19_vaccine_covid", "13_sentiment_twitter_messages", "14_ai_artificial_intelligence", "15_classification_similarit...", "16_black_racism_racist", "17_facebook_amazon_linkedin", "18_coronavirus_outbreak_dis...", "19_language_text_english", "20_tweets_twitter_tweet", "21_writer_write_writing", "22_apple_mac_apples", "23_plotly_visualizations_vi...", "24_battery_tesla_batteries", "25_spotify_music_spotifys", "26_eat_diet_coffee", "27_recommendation_recommend...", "28_neural_networks_tensorflow", "29_universe_earth_moon", "30_clustering_kmeans_detect...", "31_exercise_gym_workout", "32_frameworks_code_2020", "33_podcast_podcasts_podcast...", "34_nba_netflix_basketball", "35_photos_photographs_pictu...", "36_docker_django_flask", "37_facial_recognition_mask", "38_pepsi_marketing_branding", "39_tree_trees_forest", "40_pandemic_war_paralysisand", "41_2020_year_2020s", "42_star_nikki_olivia", "43_jupyter_notebook_notebooks", "44_classification_deep_clas...", "45_jupyterlab_jupyter_xthe", "46_san_franciscos_city", "47_ui_design_grids", "48_map_geopandas_maps", "49_pca_principal_component", "50_fuzzy_matching_nlp", "51_brain_habits_stressed", "52_airbnb_analysis_edadont", "53_math_books_mathematics", "54_nlp_summarizing_resources", "55_aws_serverless_graphql", "56_github_git_repos", "57_authentication_cognito_a...", "58_excel_sqlalchemy_database", "59_week_oct_month", "60_trading_algorithmic_cloud", "61_flask_api_quickstart", "62_gpt3_google_import", "63_nodejs_angular_nestjs", "64_router_hooks_react", "65_analysis_whale_introduct..."], "xaxis": "x", "y": ["-1_this_why_when", "0_scientist_scientists_inte...", "1_libraries_useful_functions", "2_learning_models_algorithms", "3_developer_code_programming", "4_react_app_create", "5_life_habit_successful", "6_design_ux_designer", "7_regression_bayesian_proba...", "8_dating_relationship_love", "9_visualization_charts_visu...", "10_scraping_web_scrape", "11_pandas_dataframe_frame", "12_covid19_vaccine_covid", "13_sentiment_twitter_messages", "14_ai_artificial_intelligence", "15_classification_similarit...", "16_black_racism_racist", "17_facebook_amazon_linkedin", "18_coronavirus_outbreak_dis...", "19_language_text_english", "20_tweets_twitter_tweet", "21_writer_write_writing", "22_apple_mac_apples", "23_plotly_visualizations_vi...", "24_battery_tesla_batteries", "25_spotify_music_spotifys", "26_eat_diet_coffee", "27_recommendation_recommend...", "28_neural_networks_tensorflow", "29_universe_earth_moon", "30_clustering_kmeans_detect...", "31_exercise_gym_workout", "32_frameworks_code_2020", "33_podcast_podcasts_podcast...", "34_nba_netflix_basketball", "35_photos_photographs_pictu...", "36_docker_django_flask", "37_facial_recognition_mask", "38_pepsi_marketing_branding", "39_tree_trees_forest", "40_pandemic_war_paralysisand", "41_2020_year_2020s", "42_star_nikki_olivia", "43_jupyter_notebook_notebooks", "44_classification_deep_clas...",  ...

# %%
topic_model.visualize_barchart(top_n_topics=9, n_words=5, height=800)
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-latest.min.js"></script>                <div id="af9d0638-242a-41a7-a588-50856e9449b3" class="plotly-graph-div" style="height:800px; width:800px;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("af9d0638-242a-41a7-a588-50856e9449b3")) {                    Plotly.newPlot(                        "af9d0638-242a-41a7-a588-50856e9449b3",                        [{"orientation": "h", "type": "bar", "x": [0.012724692903512769, 0.013277288912494127, 0.022288238847141196, 0.03462034899556328, 0.04484303329091001], "xaxis": "x", "y": ["questions  ", "career  ", "interview  ", "scientists  ", "scientist  "], "yaxis": "y"}, {"orientation": "h", "type": "bar", "x": [0.01237055665804816, 0.012681832536690007, 0.015376770359789266, 0.01581022208433059, 0.01808953652667822], "xaxis": "x2", "y": ["comprehension  ", "science  ", "functions  ", "useful  ", "libraries  "], "yaxis": "y2"}, {"orientation": "h", "type": "bar", "x": [0.018236085881024336, 0.01948218486023126, 0.0227672839565982, 0.02887036768514761, 0.07957643550746428], "xaxis": "x3", "y": ["model  ", "ml  ", "algorithms  ", "models  ", "learning  "], "yaxis": "y3"}, {"orientation": "h", "type": "bar", "x": [0.02886859692186898, 0.02994809046653253, 0.039117868067827376, 0.0469234482257751, 0.04719997470980393], "xaxis": "x4", "y": ["developers  ", "software  ", "programming  ", "code  ", "developer  "], "yaxis": "y4"}, {"orientation": "h", "type": "bar", "x": [0.030585880659904877, 0.03228663386329048, 0.03794395697598283, 0.03956318802389051, 0.15207701910863614], "xaxis": "x5", "y": ["hook  ", "hooks  ", "create  ", "app  ", "react  "], "yaxis": "y5"}, {"orientation": "h", "type": "bar", "x": [0.024344532667707853, 0.03150901292684448, 0.03175279273440897, 0.03222665940449726, 0.0466017853236312], "xaxis": "x6", "y": ["things  ", "habits  ", "successful  ", "habit  ", "life  "], "yaxis": "y6"}, {"orientation": "h", "type": "bar", "x": [0.027814942647449357, 0.030158879911219932, 0.059823260436740536, 0.06394218218898508, 0.1260187740202249], "xaxis": "x7", "y": ["designers  ", "portfolio  ", "designer  ", "ux  ", "design  "], "yaxis": "y7"}, {"orientation": "h", "type": "bar", "x": [0.037241724966406126, 0.050454330781961584, 0.055982141740426705, 0.06571951865815752, 0.15696108944732767], "xaxis": "x8", "y": ["likelihood  ", "distribution  ", "probability  ", "bayesian  ", "regression  "], "yaxis": "y8"}, {"orientation": "h", "type": "bar", "x": [0.023050638568914972, 0.024425165907767454, 0.033575462167591226, 0.054030138650876997, 0.06012812233428373], "xaxis": "x9", "y": ["boyfriend  ", "marriage  ", "love  ", "relationship  ", "dating  "], "yaxis": "y9"}],                        {"annotations": [{"font": {"size": 16}, "showarrow": false, "text": "Topic 0", "x": 0.11666666666666665, "xanchor": "center", "xref": "paper", "y": 0.9999999999999999, "yanchor": "bottom", "yref": "paper"}, {"font": {"size": 16}, "showarrow": false, "text": "Topic 1", "x": 0.49999999999999994, "xanchor": "center", "xref": "paper", "y": 0.9999999999999999, "yanchor": "bottom", "yref": "paper"}, {"font": {"size": 16}, "showarrow": false, "text": "Topic 2", "x": 0.8833333333333333, "xanchor": "center", "xref": "paper", "y": 0.9999999999999999, "yanchor": "bottom", "yref": "paper"}, {"font": {"size": 16}, "showarrow": false, "text": "Topic 3", "x": 0.11666666666666665, "xanchor": "center", "xref": "paper", "y": 0.6166666666666666, "yanchor": "bottom", "yref": "paper"}, {"font": {"size": 16}, "showarrow": false, "text": "Topic 4", "x": 0.49999999999999994, "xanchor": "center", "xref": "paper", "y": 0.6166666666666666, "yanchor": "bottom", "yref": "paper"}, {"font": {"size": 16}, "showarrow": false, "text": "Topic 5", "x": 0.8833333333333333, "xanchor": "center", "xref": "paper", "y": 0.6166666666666666, "yanchor": "bott ...
