# %% [markdown]
# <a href="https://colab.research.google.com/github/sejaldua/digesting-the-digest/blob/main/BERTopic_Medium_Daily_Digest.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **Tutorial** - Dynamic Topic Modeling with Trump's Tweets
# (last updated 26-04-2021)
#
# In this tutorial we will be using Dynamic Topic Modeling with BERTopic to visualize how topics in Trump's Tweets have evolved over time. These topics will be visualized and thoroughly explored.
#
# ## Dynamic Topic Models
# Dynamic topic models can be used to analyze the evolution of topics of a collection of documents over time.
#
# <br>
#
# <img src="https://raw.githubusercontent.com/MaartenGr/BERTopic/master/images/logo.png" width="40%">

# %% [markdown]
# # Enabling the GPU
#
# First, you'll need to enable GPUs for the notebook:
#
# - Navigate to Edit→Notebook Settings
# - select GPU from the Hardware Accelerator drop-down
#
# [Reference](https://colab.research.google.com/notebooks/gpu.ipynb)

# %% [markdown]
# # Installing BERTopic
#
# We start by installing BERTopic from PyPi:

# %%
# %%capture
# !pip install bertopic

# %% [markdown]
# ## Restart the Notebook
# After installing BERTopic, some packages that were already loaded were updated and in order to correctly use them, we should now restart the notebook.
#
# From the Menu:
#
# Runtime → Restart Runtime

# %% [markdown]
# # **Data**
# For this tutorial, we will be needing to extract all Trump's Tweet from his @realDonalTrump account. We will be removing all retweet and focus on his original tweets.
#
# Moreover, since we are looking at his tweets over time, we will be saving all timestamps related to his tweets.

# %%
import re
import pandas as pd
from datetime import datetime

# Load data
trump = pd.read_csv('https://drive.google.com/uc?export=download&id=1xRKHaP-QwACMydlDnyFPEaFdtskJuBa6')

# Filter
trump.text = trump.apply(lambda row: re.sub(r"http\S+", "", row.text).lower(), 1)
trump.text = trump.apply(lambda row: " ".join(filter(lambda x:x[0]!="@", row.text.split())), 1)
trump.text = trump.apply(lambda row: " ".join(re.sub("[^a-zA-Z]+", " ", row.text).split()), 1)
trump = trump.loc[(trump.isRetweet == "f") & (trump.text != ""), :]
timestamps = trump.date.to_list()
tweets = trump.text.to_list()

# %%
tweets[0]
# Out:
# 'republicans and democrats have both created our economic problems'

# %% [markdown]
# # **Dynamic Topic Modeling**

# %% [markdown]
# ## Basic Topic Model
# To perform Dynamic Topic Modeling with BERTopic we will first need to create a basic topic model using all tweets. The temporal aspect will be ignored as we are, for now, only interested in the topics that reside in those tweets.

# %%
from bertopic import BERTopic
topic_model = BERTopic(min_topic_size=35, verbose=True)
topics, _ = topic_model.fit_transform(tweets)
# Out:
# HBox(children=(FloatProgress(value=0.0, max=244715968.0), HTML(value='')))
# HBox(children=(FloatProgress(value=0.0, description='Batches', max=1418.0, style=ProgressStyle(description_wid…
# 2021-04-26 10:01:08,287 - BERTopic - Transformed documents to Embeddings
# 2021-04-26 10:02:04,547 - BERTopic - Reduced dimensionality with UMAP
# 2021-04-26 10:02:09,994 - BERTopic - Clustered UMAP embeddings with HDBSCAN

# %% [markdown]
# We can then extract most frequent topics:

# %%
freq = topic_model.get_topic_info(); freq.head(10)
# Out:
#    Topic  Count                                          Name
# 0     -1  22579                        -1_who_never_more_many
# 1     95   4392            95_donald_mr_president_donaldtrump
# 2    101    849                  101_obamacare_tax_cuts_taxes
# 3     13    742               13_china_trade_tariffs_currency
# 4     22    725                    22_run_president_vote_need
# 5     93    506                 93_obama_president_why_barack
# 6     99    494                 99_golf_scotland_club_courses
# 7     60    421  60_entrepreneurs_midas_business_entrepreneur
# 8    113    396              113_fake_story_dishonest_stories
# 9      3    391                     3_thanks_luck_owen_spence

# %% [markdown]
# -1 refers to all outliers and should typically be ignored. Next, let's take a look at a frequent topic that were generated:

# %%
topic_nr = freq.iloc[3]["Topic"]  # We select a frequent topic
topic_model.get_topic(topic_nr)   # You can select a topic number as shown above
# Out:
# [('china', 0.07573092506039296),
#  ('trade', 0.013309739185139707),
#  ('tariffs', 0.012623535078318857),
#  ('currency', 0.009461009008521506),
#  ('xi', 0.008739575330206275),
#  ('billion', 0.007595171706228625),
#  ('farmers', 0.006619308396977417),
#  ('products', 0.006389464346454614),
#  ('billions', 0.005902412687479343),
#  ('countries', 0.00538922012108594)]

# %% [markdown]
# We can visualize the basic topics that were created with the Intertopic Distance Map. This allows us to judge visually whether the basic topics are sufficient before proceeding to creating the topics over time.

# %%
fig = topic_model.visualize_topics(); fig
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-latest.min.js"></script>                <div id="3e91d83e-dcfa-441e-a336-8c32a39ed320" class="plotly-graph-div" style="height:650px; width:650px;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("3e91d83e-dcfa-441e-a336-8c32a39ed320")) {                    Plotly.newPlot(                        "3e91d83e-dcfa-441e-a336-8c32a39ed320",                        [{"customdata": [[12.0266695022583, 2.7560179233551025, 0, "thank | newt | imwithyou | negop | potusinjapan", 320], [11.825454711914062, 2.5497918128967285, 1, "fringe | frivolous | frieden | friend | friendlier", 94], [11.639708518981934, 2.4790639877319336, 2, "make | tcash | successful | fackinpeter | vital", 91], [9.824152946472168, 3.343763828277588, 3, "thanks | luck | owen | spence | grant", 391], [11.434147834777832, 2.844482660293579, 4, "churchill | enemies | winston | dragonmamba | realdonaldtrump", 107], [11.644408226013184, 2.8687431812286377, 5, "einstein | albert | henry | rules | learn", 46], [10.666515350341797, 2.9865169525146484, 6, "interesting | lightning | interestingly | revealing | insightful", 36], [4.85270357131958, 10.754081726074219, 7, "freezing | cold | coldest | ice | weather", 109], [6.424379825592041, 13.232193946838379, 8, "rasmussen | republican | polls | polling | bikersfortrump", 44], [5.87116003036499, 20.8909854888916, 9, "japan | abe | shinzo | japanese | golf", 51], [6.0200910568237305, 20.5479679107666, 10, "korea | kim | jong | nuclear | meeting", 168], [-2.597989559173584, 7.60373592376709, 11, "turbines | ugly | windfarm | windmills | aberdeen", 201], [5.733006000518799, 20.324283599853516, 12, "apple | iphone | samsung | mac | tim", 40], [6.3822784423828125, 20.54987907409668, 13, "china | trade | tariffs | currency | xi", 742], [11.687666893005371, 2.7754251956939697, 14, "wwehof | wwe | wrestlemania | fame | vince", 56], [11.197157859802246, 2.383242130279541, 15, "maga | thank | deehogan | milwaukee | rnc", 53], [11.629958152770996, 2.885003089904785, 16, "hunt | witch | ms | victor | murders", 39], [11.875724792480469, 3.5629067420959473, 17, "americafirst | bless | god | odonnelltw | okito", 48], [5.762391090393066, 20.29397964477539, 18, "germany | nato | europe | european | german", 92], [4.9022111892700195, 10.705286026000977, 19, "oil | gas | arabia | saudi | keystone", 247], [1.7304731607437134, 7.840672492980957, 20, "pennsylvania | michigan | votes | detroit | ballots", 118], [1.6407926082611084, 7.75077486038208, 21, "georgia | signature | signatures | verification | ballots", 56], [6.670595169067383, 13.340052604675293, 22, "run | president | vote | need | running", 725], [6.014176845550537, 0.41602981090545654, 23, "discussing | interview | iontv | newsmax | timetogettough", 188], [11.49013614654541, 2.617581605911255, 24, "dday | usaatunga | umakemeill | tlfordxx | mirandamattos", 48], [11.718100547790527, 2.4849743843078613, 25, "makeamericagreatagain | utahcaucus | kimmel | victorconkle | experiencevideo", 66], [13.109368324279785, 1.8946197032928467, 26, "makeamericagreatagain | makeamericasafeagain | makeamericagreatagainwatch | buyamericanhireamerican | madeinamerica", 86], [1.8424731492996216, 1.6840986013412476, 27, "billionaire | impress | success | rich | estate", 54], [3.250129461288452, -9.210564613342285, 28, "book | books | signing | copies | copy", 319], [2.644595146179199, -9.816179275512695, 29, "fox | greta | tonight | foxandfriends | reilly", 197], [11.123064994812012, 1.9851020574569702, 30, "birthday | happy | anniversary | wishes | wish", 53], [11.186607360839844, 1.9206418991088867, 31, "birthday | happy | tiffany | jamieaydt | audrey", 52], [6.97086763381958, 13.5558443069458, 32, "brady | tom | bob | kraft | quarterback", 58], [12.966124534606934, 1.9373859167099, 33, "makeamericagreatagain | gopdebate |  ...

# %% [markdown]
# ## Topics over Time
# Before we start with the Dynamic Topic Modeling step, it is important that you are satisfied with the topics that were created previously. We are going to be using those specific topics as a base for Dynamic Topic Modeling.
#
# Thus, this step will essentially show you how the topics that were defined previously have evolved over time.

# %% [markdown]
# There are a few important parameters that you should take note of, namely:
#
# * `docs`
#   * These are the tweets that we are using
# * `topics`
#   * The topics that we have created before
# * `timestamps`
#   * The timestamp of each tweet/document
# * `global_tuning`
#   * Whether to average the topic representation of a topic at time *t* with its global topic representation
# * `evolution_tuning`
#   * Whether to average the topic representation of a topic at time *t* with the topic representation of that topic at time *t-1*
# * `nr_bins`
#   * The number of bins to put our timestamps into. It is computationally inefficient to extract the topics at thousands of different timestamps. Therefore, it is advised to keep this value below 20.

# %%
topics_over_time = topic_model.topics_over_time(docs=tweets, 
                                                topics=topics, 
                                                timestamps=timestamps, 
                                                global_tuning=True, 
                                                evolution_tuning=True, 
                                                nr_bins=20)
# Out:
# 20it [01:05,  3.28s/it]

# %% [markdown]
# ## Visualize Topics over Time
# After having created our `topics_over_time`, we will have to visualize those topics as accessing them becomes a bit more difficult with the added temporal dimension.
#
# To do so, we are going to visualize the distribution of topics over time based on their frequency. Doing so allows us to see how the topics have evolved over time. Make sure to hover over any point to see how the topic representation at time *t* differs from the global topic representation.

# %%
topic_model.visualize_topics_over_time(topics_over_time, top_n=20)
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-latest.min.js"></script>                <div id="a2195d29-3a23-4d07-9c75-f55b4e071922" class="plotly-graph-div" style="height:450px; width:1250px;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("a2195d29-3a23-4d07-9c75-f55b4e071922")) {                    Plotly.newPlot(                        "a2195d29-3a23-4d07-9c75-f55b4e071922",                        [{"hoverinfo": "text", "hovertext": ["<b>Topic 28</b><br>Words: keychain, contest, book, champion, books", "<b>Topic 28</b><br>Words: paperback, bestselling, book, read, books", "<b>Topic 28</b><br>Words: book, signing, timetogettough, read, noon", "<b>Topic 28</b><br>Words: book, literary, virgil, read, edrendell", "<b>Topic 28</b><br>Words: book, read, books, reading, signing", "